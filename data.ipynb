# %% [markdown]
# <a href="https://colab.research.google.com/github/priyavanshjn/DATA-VISULISATION/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2025-06-16 225635.png](data:image/png;base64,...)
